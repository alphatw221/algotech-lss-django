# %%
import django_initializer
from backend.pymongo.mongodb import db
import pandas as pd
from datetime import datetime
import arrow
import json
import copy

# %% [markdown]
# # order analysis

# %%
class SalesReport:
    basic_info_keys = ['post_comment', 'no_of_items_sold', 'no_of_items_unsold', 'total_no_of_items', 
                   'total_inventories', 'total_no_of_orders', 'total_amount', 'average_order_value']
    order_analysis_keys = ['status', 'qty', 'percentage_of_qty', 'total', 'percentage_of_total']
    best_selling_items_top_10_keys = ['item', 'qty_for_sale', 'best_selling_status']
    
    data = {}
    
    def __init__(self):
        pass
    
    @classmethod
    def normalize_start_time(cls, start_time):
        return arrow.get(start_time).replace(hour=0, minute=0, second=0).datetime
    
    @classmethod
    def normalize_end_time(cls, end_time):
        return arrow.get(end_time).replace(hour=23, minute=59, second=59).datetime
    
    @classmethod
    def get_basic_info(cls, start_time, end_time):
        query=db.api_campaign.aggregate([
            {
                "$match":{
                    "start_at":{
                        "$gte": start_time
                    },
                    "end_at": {
                        "$lte": end_time
                    }
                }
            },
            {
                "$lookup": {
                    "from": "api_campaign_comment",
                    "as": "campaign_comment",
                    'let': {'id': "$id" },
                    "pipeline":[
                        {"$match":{
                            '$expr': { '$eq': ["$$id", "$campaign_id"] },
                            "id":{"$ne":None}}
                        }
                    ]
                },
            },
            {
                "$lookup": {
                    "from": "api_campaign_product",
                    "as": "campaign_product_sold", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                                "qty_sold": {
                                    "$gt": 0
                                }
                            }
                        }
                    ]
                },
            },
            {
                "$lookup": {
                    "from": "api_campaign_product",
                    "as": "campaign_product_unsold", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                                "qty_sold": {
                                    "$eq": 0
                                }
                            }
                        }
                    ]
                },
            },
            {
                "$lookup": {
                    "from": "api_campaign_product",
                    "as": "campaign_product_total_item", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                            }
                        }
                    ]
                },
            },
            {
                "$lookup": {
                    "from": "api_order",
                    "as": "orders", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                            }
                        },
                        {
                            "$project":{
                                "_id":0,
                                "id":1,
                                "total":1
                            }
                        }
                    ]
                },
            },
            {
                "$lookup": {
                    "from": "api_pre_order",
                    "as": "pre_orders", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                            }
                        },
                        {
                            "$project":{
                                "_id":0,
                                "id":1,
                                "total":1
                            }
                        }
                    ]
                },
            },
            {
                "$project":{
                    "_id":0,
                    "campaign_id":"$id",
                    "start_at": "$start_at",
                    "end_at": "$end_at",
                    "post_comment":{"$size":"$campaign_comment.id"},
                    "no_of_items_sold":{"$size": "$campaign_product_sold.id"},
                    "no_of_items_unsold":{"$size": "$campaign_product_unsold.id"},
                    "total_no_of_items":{"$size": "$campaign_product_total_item.id"},
                    "total_inventories":{"$sum": "$campaign_product_total_item.qty_for_sale"},
                    "total_no_of_orders": {"$add":[{"$size": "$pre_orders.id"},{"$size": "$orders.id"}]},
                    "total_amount": {"$add":[{"$sum": "$pre_orders.total"},{"$sum": "$orders.total"}]},
                    "average_order_value":{ "$divide": [{"$add":[{"$sum": "$pre_orders.total"},{"$sum": "$orders.total"}]}, 2 ] }
                }
            },
            { "$sort" : { "campaign_id" : 1 } }
        ])
        df = json_normalize(list(query))
        return df
    
    @classmethod
    def get_top_10_itmes(cls, start_time, end_time):
        query=db.api_campaign.aggregate([
            {
                "$match":{
                    "start_at":{
                        "$gte": start_time
                    },
                    "end_at": {
                        "$lte": end_time
                    }
                }
            },
            {
                "$lookup": {
                    "from": "api_campaign_product",
                    "as": "campaign_product", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                            }
                        },
                        {
                            "$lookup": {
                                "from": "api_order_product",
                                "as": "order_product", 
                                'let': {'id': "$id" },
                                "pipeline":[
                                    {
                                        "$match":{

                                            '$expr': {"$eq": ["$$id", "$campaign_product_id"]},
                                            "id":{"$ne":None},
                                        }
                                    },
                                    {
                                        "$project":{
                                            "_id":0,
                                            "qty":1,
                                        }
                                    }
                                ]
                            },
                        },
                        {
                            "$project":{
                                "_id":0,
                                "name":1,
                                "order_product_qty":{"$sum":"$order_product.qty"},
                                "qty_for_sale":1,
                                "status": {
                                    "$switch": {
                                      "branches": [
                                        {
                                          "case": {"$eq": ["$qty_for_sale", {"$sum":"$order_product.qty"}] },
                                          "then": "Sold Out"
                                        }
                                      ],
                                      "default": ""
                                    }

                                }
                            }
                        },
                        {"$sort": {"order_product_qty":-1}},
                        { "$limit": 10 }
                    ]
                },
            },
            {
                "$project":{
                    "_id":0,
                    "campaign_id":"$id",
                    "item": "$campaign_product.name",
                    "qty_for_sale": "$campaign_product.qty_for_sale",
#                     "order_product_qty": "$campaign_product.order_product_qty",
                    "best_selling_status": "$campaign_product.status"

                }
            },
            { "$sort" : { "campaign_id" : 1 } }

        ])
        df = json_normalize(list(query))
        return df
    @classmethod
    def get_order_data(cls, start_time, end_time):
    
        cursor=db.api_campaign.aggregate([
            {
                "$match":{
                    "start_at":{
                        "$gte": start_time
                    },
                    "end_at": {
                        "$lte": end_time
                    }
                }
            },
            {
                "$lookup": {
                    "from": "api_order",
                    "as": "orders", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                            }
                        },
                        {"$addFields": { "new_type": "$status"}}
                    ]
                },
            },
            {
                "$lookup": {
                    "from": "api_pre_order",
                    "as": "pre_orders", 
                    'let': {'id': "$id" },
                    "pipeline":[
                        {
                            "$match":{
                                '$expr': { '$eq': ["$$id", "$campaign_id"] },
                                "id":{"$ne":None},
                                "subtotal": {"$ne" : 0}
                            }
                        },
                        {"$addFields": { "new_type": "cart"}}
                    ]
                },
            },
            {"$project":{"_id":0,"data":{"$concatArrays":["$orders","$pre_orders"]}}},
            { "$unwind": "$data" },
            { "$group": {
                    "_id": {
                        "id": "$data.campaign_id",
                        "status": "$data.new_type"
                    },
                    "campaign_id": {"$first": "$data.campaign_id"},
                    "status": {"$first": "$data.new_type"},
                    "qty": {"$sum": 1},
                    "total": {"$sum": "$data.total"}
               }
            },
            {
                "$project":{
                    "_id":0,

                }
            },

            { "$sort" : { "campaign_id" : 1 } }
        ])
        return list(cursor)
    @classmethod
    def modify_order_data(cls, report):
        def checkLack(x):
            if len(x) == 1 and x[0] == "paid":
                return "unpaid"
            elif len(x) == 1 and x[0] == "unpaid":
                return "paid"
            else:
                return ""
        def insert_0(x):
            cols = ['qty', 'total', 'percentage_of_qty', 'percentage_of_total']
            if x["lack"] == "paid":
                return [[0] + x[col] for col in cols]
            elif x["lack"] == "unpaid":
                return [x[col] + [0] for col in cols]
            else:
                return [x[col] for col in cols]

        df = json_normalize(report)
        df.loc[:,"new_status"] = df["status"].apply(lambda x: 'unpaid' if x in ['review', 'cart'] else 'paid')
        df = df.groupby(["campaign_id", "new_status"]).agg({'qty': 'sum', 'total': 'sum'}).reset_index()

        df = df.groupby(["campaign_id"]).agg({'new_status': list, 'qty': list, 'total':list}).reset_index()
        df.loc[:, "lack"] = df["new_status"].apply(checkLack)


        df.loc[:, "percentage_of_qty"] = df["qty"].apply(lambda x: [round(i/sum(x)*100,2) for i in x])
        df.loc[:, "percentage_of_total"] = df["total"].apply(lambda x: [round(i/sum(x)*100,2) for i in x])


        df["qty"], df["total"], df['percentage_of_qty'], df['percentage_of_total'] = zip(*df.apply(insert_0, axis=1))
        df.loc[:, "status"] = df.apply(lambda _: ["paid", "unpaid"], axis=1)
        df = df[["campaign_id", "status", "qty", "percentage_of_qty", "total", "percentage_of_total"]]
        return df
   
    @classmethod
    def get_order_analysis(cls, start_time, end_time):
        data = SalesReport.get_order_data(start_time, end_time)
        report = SalesReport.modify_order_data(data)
        return report
    
    @classmethod
    def merge_data(cls, basic_info, top_10_itmes, order_analysis):

        df = basic_info.merge(top_10_itmes, on="campaign_id", how="outer").merge(order_analysis, on="campaign_id", how="outer")
        result = df.to_json(orient="records")
        json_data = json.loads(result)
        
        campaign_template = {
            "campaign_id":"",
            "start_at": "",
            "end_at": "",
            "basic_info": {},
            "order_analysis": {},
            "best_selling_items_top_10": {}
        }

        for row in json_data:
            new_row_data = copy.deepcopy(row)
            new_data = copy.deepcopy(campaign_template)
            for key in new_data:
                if key == "basic_info":
                    for b_key in cls.basic_info_keys:
                        new_data[key][b_key] = new_row_data[b_key]
                elif key == "order_analysis":
                    for o_key in cls.order_analysis_keys:
                        new_data[key][o_key] = new_row_data[o_key]
                elif key == "best_selling_items_top_10":
                    for s_key in cls.best_selling_items_top_10_keys:
                        if s_key == "best_selling_status":
                            new_data[key]['status'] = new_row_data[s_key]
                        else:
                            new_data[key][s_key] = new_row_data[s_key]
                else:
                    new_data[key] = new_row_data[key]
            list_data.append(new_data.copy())
        cls.data = list_data
        return list_dat

# %%
start_time = SalesReport.normalize_start_time("2022-06-15")
end_time = SalesReport.normalize_end_time("2022-06-20")
basic_info = SalesReport.get_basic_info(start_time, end_time)
top_10_itmes = SalesReport.get_top_10_itmes(start_time, end_time)
order_report = SalesReport.get_order_analysis(start_time, end_time)

# %%
display(basic_info)
# Out:
#     campaign_id                start_at                  end_at  post_comment  \
# 0           494 2022-06-15 02:10:00.000 2022-06-17 07:25:00.000            50
# 1           495 2022-06-15 07:00:00.000 2022-06-15 08:00:00.000             2
# 2           496 2022-06-15 07:11:00.000 2022-06-15 09:12:00.000             4
# 3           497 2022-06-15 08:49:00.000 2022-06-15 09:35:00.000            14
# 4           499 2022-06-15 08:50:00.000 2022-06-15 09:35:00.000            13
# 5           500 2022-06-15 10:20:00.000 2022-06-16 09:20:00.000            10
# 6           501 2022-06-15 09:40:00.000 2022-06-15 10:40:00.000            16
# 7           502 2022-06-15 09:50:00.000 2022-06-15 11:00:00.000             4
# 8           505 2022-06-17 07:06:00.000 2022-06-17 07:06:00.000             0
# 9           506 2022-06-17 07:02:00.000 2022-06-17 07:03:00.000             0
# 10          507 2022-06-17 07:25:00.000 2022-06-17 07:25:00.000             4
# 11          508 2022-06-16 08:52:00.000 2022-06-16 10:51:00.000             0
# 12          509 2022-06-17 02:50:00.000 2022-06-18 02:24:00.000           103
# 13          510 2022-06-17 04:07:00.000 2022-06-17 08:56:00.000             7
# 14          512 2022-06-17 08:08:00.000 2022-06-17 11:07:00.000            11
# 15          513 2022-06-17 08:31:00.000 2022-06-17 09:03:00.000            19
# 16          514 2022-06-17 08:56:00.000 2022-06-17 09:51:00.000             0
# 17          515 2022-06-17 09:50:00.000 2022-06-17 10:49:00.000             2
# 18          516 2022-06-18 09:57:00.000 2022-06-19 09:58:00.000             0
# 19          517 2022-06-17 10:33:00.000 2022-06-17 12:34:00.000             9
# 20          520 2022-06-20 08:03:00.000 2022-06-20 08:58:00.000             9
# 21          521 2022-06-20 08:16:00.000 2022-06-20 08:57:00.000            10
# 22          522 2022-06-20 08:38:00.000 2022-06-20 08:58:00.000             4
# 23          523 2022-06-20 08:50:00.000 2022-06-20 09:17:00.000            11
# 24          524 2022-06-20 09:00:00.000 2022-06-20 10:30:00.000             7
# 25          525 2022-06-20 09:50:00.000 2022-06-20 14:15:00.000            15
# 26          639 2022-06-15 18:10:33.623 2022-06-16 18:10:33.623             0
#
#     no_of_items_sold  no_of_items_unsold  total_no_of_items  \
# 0                  4                   0                  4
# 1                  1                   2                  3
# 2                  4                   2                  6
# 3                  1                   1                  2
# 4                  3                   1                  4
# 5                  2                   0                  2
# 6                  2                   1                  3
# 7                  2                   2                  4
# 8                  0                   0                  0
# 9                  0                   0                  0
# 10                 2                   0                  2
# 11                 0                   0                  0
# 12                 1                   0                  1
# 13                 4                   0                  4
# 14                 2                   0                  2
# 15                 3                   1                  4
# 16                 0                   3                  3
# 17                 1                   0                  1
# 18                 0                   2                  2
# 19                 2                   1                  3
# 20                 3                   0                  3
# 21                 3                   0                  3
# 22                 1                   0                  1
# 23                 3                   0                  3
# 24                 2                   2                  4
# 25                 1                   1                  2
# 26                 0                   0                  0
#
#     total_inventories  total_no_of_orders  total_amount  average_order_value
# 0                 216                  16      32280.50            16140.250
# 1                1000                   1         15.99                7.995
# 2                1050                   3        159.90               79.950
# 3                 115                   4         40.00               20.000
# 4                 400                   2       8870.00             4435.000
# 5                 200                   6        191.00               95.500
# 6                  58                   4       1660.00              830.000
# 7                 900                   2         29.54               14.770
# 8                   0                   0          0.00                0.000
# 9                   0                   0          0.00                0.000
# 10                 32                   2      10683.00             5341.500
# 11                  0                   0          0.00                0.000
# 12                 50                   4       2700.00             1350.000
# 13               1110                   6        119.06               59.530
# 14                110                   7        442.10              221.050
# 15                256                   4       2420.00             1210.000
# 16                110                   0          0.00                0.000
# 17                100                   2         11.00                5.500
# 18                100                   0          0.00                0.000
# 19                810                   7       5769.00             2884.500
# 20                105                   3       1060.00              530.000
# 21                330                   4       1840.00              920.000
# 22                100                   2         10.00                5.000
# 23                 37                   3       2060.00             1030.000
# 24                310                   2        340.00              170.000
# 25                 50                   6      29200.00            14600.000
# 26                  0                   0          0.00                0.000

# %%
display(top_10_itmes)
# Out:
#     campaign_id                                               item  \
# 0           494  [Vegetable Box A, GSI Cooking Set, MSR 2person...
# 1           495                                [Top, Jeans, Skirt]
# 2           496  [grapegfruit, Pepsi, Skirt, Thai Meow Tea, pri...
# 3           497                               [nina0615, nina0615]
# 4           499      [cc013, cecitest12, cecitest5gift, cecitest6]
# 5           500              [Meja Lipat 100x40, Meja lipat 80x40]
# 6           501           [Lynn_0615, 0608lynnlucky draw, ll615_2]
# 7           502                            [Top, b1, Jeans, Skirt]
# 8           505                                                 []
# 9           506                                                 []
# 10          507                [Vegetable Box A, MSR 2person Tent]
# 11          508                                                 []
# 12          509                         [Edmark Smart Steam Brush]
# 13          510  [prize yummy cookies, Thai Meow Tea, Pepsi, 2362]
# 14          512                        [Cheese Cake, prize cookie]
# 15          513                     [PIZZA, SATAY, UTENSILS, 3659]
# 16          514                [Vegetable Box A, nina1, ninatest1]
# 17          515                                     [ninatest0617]
# 18          516              [Meja Lipat 100x40, Meja lipat 80x40]
# 19          517  [Vegetable Box A, MSR 2person Tent, prize yumm...
# 20          520                      [ice cream, cookies, Lollies]
# 21          521              [Yummy cake, prize yummy cookies, rr]
# 22          522                                     [ninatest0620]
# 23          523       [lltest_0620, 0608lynnlucky draw, Lynn_0615]
# 24          524      [cecitest8, cecitest5gift, cecitest16, cc013]
# 25          525                                 [VAN0620, VAN0620]
# 26          639                                                 []
#
#                     qty_for_sale       best_selling_status
# 0                [200, 10, 5, 1]  [, , Sold Out, Sold Out]
# 1                [200, 500, 300]                    [, , ]
# 2   [200, 300, 400, 100, 40, 10]              [, , , , , ]
# 3                      [100, 15]                      [, ]
# 4           [100, 100, 100, 100]                  [, , , ]
# 5                     [100, 100]                      [, ]
# 6                     [50, 3, 5]                    [, , ]
# 7           [250, 150, 300, 200]                  [, , , ]
# 8                             []                        []
# 9                             []                        []
# 10                       [30, 2]              [, Sold Out]
# 11                            []                        []
# 12                          [50]                        []
# 13           [10, 800, 200, 100]          [Sold Out, , , ]
# 14                     [100, 10]                      [, ]
# 15              [150, 100, 5, 1]                  [, , , ]
# 16                  [10, 100, 0]            [, , Sold Out]
# 17                         [100]                        []
# 18                      [50, 50]                      [, ]
# 19                [200, 600, 10]                    [, , ]
# 20                   [50, 50, 5]                    [, , ]
# 21                [100, 10, 220]                    [, , ]
# 22                         [100]                        []
# 23                   [20, 2, 15]                    [, , ]
# 24           [100, 10, 100, 100]                  [, , , ]
# 25                       [50, 0]              [, Sold Out]
# 26                            []                        []

# %%
display(order_report)
# Out:
#     campaign_id          status      qty percentage_of_qty  \
# 0           494  [paid, unpaid]  [2, 11]    [15.38, 84.62]
# 1           495  [paid, unpaid]   [0, 1]        [0, 100.0]
# 2           496  [paid, unpaid]   [1, 1]      [50.0, 50.0]
# 3           497  [paid, unpaid]   [2, 1]    [66.67, 33.33]
# 4           499  [paid, unpaid]   [1, 0]        [100.0, 0]
# 5           500  [paid, unpaid]   [2, 2]      [50.0, 50.0]
# 6           501  [paid, unpaid]   [1, 2]    [33.33, 66.67]
# 7           502  [paid, unpaid]   [0, 1]        [0, 100.0]
# 8           507  [paid, unpaid]   [0, 2]        [0, 100.0]
# 9           509  [paid, unpaid]   [0, 3]        [0, 100.0]
# 10          510  [paid, unpaid]   [2, 4]    [33.33, 66.67]
# 11          512  [paid, unpaid]   [2, 2]      [50.0, 50.0]
# 12          513  [paid, unpaid]   [2, 1]    [66.67, 33.33]
# 13          515  [paid, unpaid]   [1, 0]        [100.0, 0]
# 14          517  [paid, unpaid]   [1, 5]    [16.67, 83.33]
# 15          520  [paid, unpaid]   [1, 1]      [50.0, 50.0]
# 16          521  [paid, unpaid]   [1, 2]    [33.33, 66.67]
# 17          522  [paid, unpaid]   [1, 0]        [100.0, 0]
# 18          523  [paid, unpaid]   [1, 1]      [50.0, 50.0]
# 19          524  [paid, unpaid]   [1, 0]        [100.0, 0]
# 20          525  [paid, unpaid]   [0, 4]        [0, 100.0]
#
#                          total percentage_of_total
# 0             [322.0, 31758.5]         [1.0, 99.0]
# 1                   [0, 15.99]          [0, 100.0]
# 2              [127.92, 31.98]        [80.0, 20.0]
# 3                 [25.0, 15.0]        [62.5, 37.5]
# 4                  [8870.0, 0]          [100.0, 0]
# 5                [51.0, 140.0]        [26.7, 73.3]
# 6              [390.0, 1270.0]      [23.49, 76.51]
# 7                   [0, 19.54]          [0, 100.0]
# 8                 [0, 10683.0]          [0, 100.0]
# 9                  [0, 2700.0]          [0, 100.0]
# 10  [64.99000000000001, 54.07]      [54.59, 45.41]
# 11             [241.05, 81.05]      [74.84, 25.16]
# 12             [1620.0, 800.0]      [66.94, 33.06]
# 13                   [11.0, 0]          [100.0, 0]
# 14             [5161.0, 573.0]       [90.01, 9.99]
# 15              [810.0, 250.0]      [76.42, 23.58]
# 16               [0.0, 1840.0]        [0.0, 100.0]
# 17                   [10.0, 0]          [100.0, 0]
# 18             [1080.0, 980.0]      [52.43, 47.57]
# 19                  [220.0, 0]          [100.0, 0]
# 20                [0, 28800.0]          [0, 100.0]

# %%
df = basic_info.merge(top_10_itmes, on="campaign_id", how="outer").merge(order_report, on="campaign_id", how="outer")
result = df.to_json(orient="records")
json_data = json.loads(result)
display(json_data)
# Out:
# [{'campaign_id': 494,
#   'start_at': 1655259000000,
#   'end_at': 1655450700000,
#   'post_comment': 50,
#   'no_of_items_sold': 4,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 4,
#   'total_inventories': 216,
#   'total_no_of_orders': 16,
#   'total_amount': 32280.5,
#   'average_order_value': 16140.25,
#   'item': ['Vegetable Box A',
#    'GSI Cooking Set',
#    'MSR 2person Tent',
#    'RC2 - Test'],
#   'qty_for_sale': [200, 10, 5, 1],
#   'best_selling_status': ['', '', 'Sold Out', 'Sold Out'],
#   'status': ['paid', 'unpaid'],
#   'qty': [2, 11],
#   'percentage_of_qty': [15.38, 84.62],
#   'total': [322.0, 31758.5],
#   'percentage_of_total': [1.0, 99.0]},
#  {'campaign_id': 495,
#   'start_at': 1655276400000,
#   'end_at': 1655280000000,
#   'post_comment': 2,
#   'no_of_items_sold': 1,
#   'no_of_items_unsold': 2,
#   'total_no_of_items': 3,
#   'total_inventories': 1000,
#   'total_no_of_orders': 1,
#   'total_amount': 15.99,
#   'average_order_value': 7.995,
#   'item': ['Top', 'Jeans', 'Skirt'],
#   'qty_for_sale': [200, 500, 300],
#   'best_selling_status': ['', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [0, 1],
#   'percentage_of_qty': [0, 100.0],
#   'total': [0, 15.99],
#   'percentage_of_total': [0, 100.0]},
#  {'campaign_id': 496,
#   'start_at': 1655277060000,
#   'end_at': 1655284320000,
#   'post_comment': 4,
#   'no_of_items_sold': 4,
#   'no_of_items_unsold': 2,
#   'total_no_of_items': 6,
#   'total_inventories': 1050,
#   'total_no_of_orders': 3,
#   'total_amount': 159.9,
#   'average_order_value': 79.95,
#   'item': ['grapegfruit',
#    'Pepsi',
#    'Skirt',
#    'Thai Meow Tea',
#    'prize yummy cookies',
#    'Prize - Bag'],
#   'qty_for_sale': [200, 300, 400, 100, 40, 10],
#   'best_selling_status': ['', '', '', '', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 1],
#   'percentage_of_qty': [50.0, 50.0],
#   'total': [127.92, 31.98],
#   'percentage_of_total': [80.0, 20.0]},
#  {'campaign_id': 497,
#   'start_at': 1655282940000,
#   'end_at': 1655285700000,
#   'post_comment': 14,
#   'no_of_items_sold': 1,
#   'no_of_items_unsold': 1,
#   'total_no_of_items': 2,
#   'total_inventories': 115,
#   'total_no_of_orders': 4,
#   'total_amount': 40.0,
#   'average_order_value': 20.0,
#   'item': ['nina0615', 'nina0615'],
#   'qty_for_sale': [100, 15],
#   'best_selling_status': ['', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [2, 1],
#   'percentage_of_qty': [66.67, 33.33],
#   'total': [25.0, 15.0],
#   'percentage_of_total': [62.5, 37.5]},
#  {'campaign_id': 499,
#   'start_at': 1655283000000,
#   'end_at': 1655285700000,
#   'post_comment': 13,
#   'no_of_items_sold': 3,
#   'no_of_items_unsold': 1,
#   'total_no_of_items': 4,
#   'total_inventories': 400,
#   'total_no_of_orders': 2,
#   'total_amount': 8870.0,
#   'average_order_value': 4435.0,
#   'item': ['cc013', 'cecitest12', 'cecitest5gift', 'cecitest6'],
#   'qty_for_sale': [100, 100, 100, 100],
#   'best_selling_status': ['', '', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 0],
#   'percentage_of_qty': [100.0, 0],
#   'total': [8870.0, 0],
#   'percentage_of_total': [100.0, 0]},
#  {'campaign_id': 500,
#   'start_at': 1655288400000,
#   'end_at': 1655371200000,
#   'post_comment': 10,
#   'no_of_items_sold': 2,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 2,
#   'total_inventories': 200,
#   'total_no_of_orders': 6,
#   'total_amount': 191.0,
#   'average_order_value': 95.5,
#   'item': ['Meja Lipat 100x40', 'Meja lipat 80x40'],
#   'qty_for_sale': [100, 100],
#   'best_selling_status': ['', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [2, 2],
#   'percentage_of_qty': [50.0, 50.0],
#   'total': [51.0, 140.0],
#   'percentage_of_total': [26.7, 73.3]},
#  {'campaign_id': 501,
#   'start_at': 1655286000000,
#   'end_at': 1655289600000,
#   'post_comment': 16,
#   'no_of_items_sold': 2,
#   'no_of_items_unsold': 1,
#   'total_no_of_items': 3,
#   'total_inventories': 58,
#   'total_no_of_orders': 4,
#   'total_amount': 1660.0,
#   'average_order_value': 830.0,
#   'item': ['Lynn_0615', '0608lynnlucky draw', 'll615_2'],
#   'qty_for_sale': [50, 3, 5],
#   'best_selling_status': ['', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 2],
#   'percentage_of_qty': [33.33, 66.67],
#   'total': [390.0, 1270.0],
#   'percentage_of_total': [23.49, 76.51]},
#  {'campaign_id': 502,
#   'start_at': 1655286600000,
#   'end_at': 1655290800000,
#   'post_comment': 4,
#   'no_of_items_sold': 2,
#   'no_of_items_unsold': 2,
#   'total_no_of_items': 4,
#   'total_inventories': 900,
#   'total_no_of_orders': 2,
#   'total_amount': 29.54,
#   'average_order_value': 14.77,
#   'item': ['Top', 'b1', 'Jeans', 'Skirt'],
#   'qty_for_sale': [250, 150, 300, 200],
#   'best_selling_status': ['', '', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [0, 1],
#   'percentage_of_qty': [0, 100.0],
#   'total': [0, 19.54],
#   'percentage_of_total': [0, 100.0]},
#  {'campaign_id': 505,
#   'start_at': 1655449560000,
#   'end_at': 1655449560000,
#   'post_comment': 0,
#   'no_of_items_sold': 0,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 0,
#   'total_inventories': 0,
#   'total_no_of_orders': 0,
#   'total_amount': 0.0,
#   'average_order_value': 0.0,
#   'item': [],
#   'qty_for_sale': [],
#   'best_selling_status': [],
#   'status': None,
#   'qty': None,
#   'percentage_of_qty': None,
#   'total': None,
#   'percentage_of_total': None},
#  {'campaign_id': 506,
#   'start_at': 1655449320000,
#   'end_at': 1655449380000,
#   'post_comment': 0,
#   'no_of_items_sold': 0,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 0,
#   'total_inventories': 0,
#   'total_no_of_orders': 0,
#   'total_amount': 0.0,
#   'average_order_value': 0.0,
#   'item': [],
#   'qty_for_sale': [],
#   'best_selling_status': [],
#   'status': None,
#   'qty': None,
#   'percentage_of_qty': None,
#   'total': None,
#   'percentage_of_total': None},
#  {'campaign_id': 507,
#   'start_at': 1655450700000,
#   'end_at': 1655450700000,
#   'post_comment': 4,
#   'no_of_items_sold': 2,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 2,
#   'total_inventories': 32,
#   'total_no_of_orders': 2,
#   'total_amount': 10683.0,
#   'average_order_value': 5341.5,
#   'item': ['Vegetable Box A', 'MSR 2person Tent'],
#   'qty_for_sale': [30, 2],
#   'best_selling_status': ['', 'Sold Out'],
#   'status': ['paid', 'unpaid'],
#   'qty': [0, 2],
#   'percentage_of_qty': [0, 100.0],
#   'total': [0, 10683.0],
#   'percentage_of_total': [0, 100.0]},
#  {'campaign_id': 508,
#   'start_at': 1655369520000,
#   'end_at': 1655376660000,
#   'post_comment': 0,
#   'no_of_items_sold': 0,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 0,
#   'total_inventories': 0,
#   'total_no_of_orders': 0,
#   'total_amount': 0.0,
#   'average_order_value': 0.0,
#   'item': [],
#   'qty_for_sale': [],
#   'best_selling_status': [],
#   'status': None,
#   'qty': None,
#   'percentage_of_qty': None,
#   'total': None,
#   'percentage_of_total': None},
#  {'campaign_id': 509,
#   'start_at': 1655434200000,
#   'end_at': 1655519040000,
#   'post_comment': 103,
#   'no_of_items_sold': 1,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 1,
#   'total_inventories': 50,
#   'total_no_of_orders': 4,
#   'total_amount': 2700.0,
#   'average_order_value': 1350.0,
#   'item': ['Edmark Smart Steam Brush'],
#   'qty_for_sale': [50],
#   'best_selling_status': [''],
#   'status': ['paid', 'unpaid'],
#   'qty': [0, 3],
#   'percentage_of_qty': [0, 100.0],
#   'total': [0, 2700.0],
#   'percentage_of_total': [0, 100.0]},
#  {'campaign_id': 510,
#   'start_at': 1655438820000,
#   'end_at': 1655456160000,
#   'post_comment': 7,
#   'no_of_items_sold': 4,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 4,
#   'total_inventories': 1110,
#   'total_no_of_orders': 6,
#   'total_amount': 119.06,
#   'average_order_value': 59.53,
#   'item': ['prize yummy cookies', 'Thai Meow Tea', 'Pepsi', '2362'],
#   'qty_for_sale': [10, 800, 200, 100],
#   'best_selling_status': ['Sold Out', '', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [2, 4],
#   'percentage_of_qty': [33.33, 66.67],
#   'total': [64.99, 54.07],
#   'percentage_of_total': [54.59, 45.41]},
#  {'campaign_id': 512,
#   'start_at': 1655453280000,
#   'end_at': 1655464020000,
#   'post_comment': 11,
#   'no_of_items_sold': 2,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 2,
#   'total_inventories': 110,
#   'total_no_of_orders': 7,
#   'total_amount': 442.1,
#   'average_order_value': 221.05,
#   'item': ['Cheese Cake', 'prize cookie'],
#   'qty_for_sale': [100, 10],
#   'best_selling_status': ['', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [2, 2],
#   'percentage_of_qty': [50.0, 50.0],
#   'total': [241.05, 81.05],
#   'percentage_of_total': [74.84, 25.16]},
#  {'campaign_id': 513,
#   'start_at': 1655454660000,
#   'end_at': 1655456580000,
#   'post_comment': 19,
#   'no_of_items_sold': 3,
#   'no_of_items_unsold': 1,
#   'total_no_of_items': 4,
#   'total_inventories': 256,
#   'total_no_of_orders': 4,
#   'total_amount': 2420.0,
#   'average_order_value': 1210.0,
#   'item': ['PIZZA', 'SATAY', 'UTENSILS', '3659'],
#   'qty_for_sale': [150, 100, 5, 1],
#   'best_selling_status': ['', '', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [2, 1],
#   'percentage_of_qty': [66.67, 33.33],
#   'total': [1620.0, 800.0],
#   'percentage_of_total': [66.94, 33.06]},
#  {'campaign_id': 514,
#   'start_at': 1655456160000,
#   'end_at': 1655459460000,
#   'post_comment': 0,
#   'no_of_items_sold': 0,
#   'no_of_items_unsold': 3,
#   'total_no_of_items': 3,
#   'total_inventories': 110,
#   'total_no_of_orders': 0,
#   'total_amount': 0.0,
#   'average_order_value': 0.0,
#   'item': ['Vegetable Box A', 'nina1', 'ninatest1'],
#   'qty_for_sale': [10, 100, 0],
#   'best_selling_status': ['', '', 'Sold Out'],
#   'status': None,
#   'qty': None,
#   'percentage_of_qty': None,
#   'total': None,
#   'percentage_of_total': None},
#  {'campaign_id': 515,
#   'start_at': 1655459400000,
#   'end_at': 1655462940000,
#   'post_comment': 2,
#   'no_of_items_sold': 1,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 1,
#   'total_inventories': 100,
#   'total_no_of_orders': 2,
#   'total_amount': 11.0,
#   'average_order_value': 5.5,
#   'item': ['ninatest0617'],
#   'qty_for_sale': [100],
#   'best_selling_status': [''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 0],
#   'percentage_of_qty': [100.0, 0],
#   'total': [11.0, 0],
#   'percentage_of_total': [100.0, 0]},
#  {'campaign_id': 516,
#   'start_at': 1655546220000,
#   'end_at': 1655632680000,
#   'post_comment': 0,
#   'no_of_items_sold': 0,
#   'no_of_items_unsold': 2,
#   'total_no_of_items': 2,
#   'total_inventories': 100,
#   'total_no_of_orders': 0,
#   'total_amount': 0.0,
#   'average_order_value': 0.0,
#   'item': ['Meja Lipat 100x40', 'Meja lipat 80x40'],
#   'qty_for_sale': [50, 50],
#   'best_selling_status': ['', ''],
#   'status': None,
#   'qty': None,
#   'percentage_of_qty': None,
#   'total': None,
#   'percentage_of_total': None},
#  {'campaign_id': 517,
#   'start_at': 1655461980000,
#   'end_at': 1655469240000,
#   'post_comment': 9,
#   'no_of_items_sold': 2,
#   'no_of_items_unsold': 1,
#   'total_no_of_items': 3,
#   'total_inventories': 810,
#   'total_no_of_orders': 7,
#   'total_amount': 5769.0,
#   'average_order_value': 2884.5,
#   'item': ['Vegetable Box A', 'MSR 2person Tent', 'prize yummy cookies'],
#   'qty_for_sale': [200, 600, 10],
#   'best_selling_status': ['', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 5],
#   'percentage_of_qty': [16.67, 83.33],
#   'total': [5161.0, 573.0],
#   'percentage_of_total': [90.01, 9.99]},
#  {'campaign_id': 520,
#   'start_at': 1655712180000,
#   'end_at': 1655715480000,
#   'post_comment': 9,
#   'no_of_items_sold': 3,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 3,
#   'total_inventories': 105,
#   'total_no_of_orders': 3,
#   'total_amount': 1060.0,
#   'average_order_value': 530.0,
#   'item': ['ice cream', 'cookies', 'Lollies'],
#   'qty_for_sale': [50, 50, 5],
#   'best_selling_status': ['', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 1],
#   'percentage_of_qty': [50.0, 50.0],
#   'total': [810.0, 250.0],
#   'percentage_of_total': [76.42, 23.58]},
#  {'campaign_id': 521,
#   'start_at': 1655712960000,
#   'end_at': 1655715420000,
#   'post_comment': 10,
#   'no_of_items_sold': 3,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 3,
#   'total_inventories': 330,
#   'total_no_of_orders': 4,
#   'total_amount': 1840.0,
#   'average_order_value': 920.0,
#   'item': ['Yummy cake', 'prize yummy cookies', 'rr'],
#   'qty_for_sale': [100, 10, 220],
#   'best_selling_status': ['', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 2],
#   'percentage_of_qty': [33.33, 66.67],
#   'total': [0.0, 1840.0],
#   'percentage_of_total': [0.0, 100.0]},
#  {'campaign_id': 522,
#   'start_at': 1655714280000,
#   'end_at': 1655715480000,
#   'post_comment': 4,
#   'no_of_items_sold': 1,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 1,
#   'total_inventories': 100,
#   'total_no_of_orders': 2,
#   'total_amount': 10.0,
#   'average_order_value': 5.0,
#   'item': ['ninatest0620'],
#   'qty_for_sale': [100],
#   'best_selling_status': [''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 0],
#   'percentage_of_qty': [100.0, 0],
#   'total': [10.0, 0],
#   'percentage_of_total': [100.0, 0]},
#  {'campaign_id': 523,
#   'start_at': 1655715000000,
#   'end_at': 1655716620000,
#   'post_comment': 11,
#   'no_of_items_sold': 3,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 3,
#   'total_inventories': 37,
#   'total_no_of_orders': 3,
#   'total_amount': 2060.0,
#   'average_order_value': 1030.0,
#   'item': ['lltest_0620', '0608lynnlucky draw', 'Lynn_0615'],
#   'qty_for_sale': [20, 2, 15],
#   'best_selling_status': ['', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 1],
#   'percentage_of_qty': [50.0, 50.0],
#   'total': [1080.0, 980.0],
#   'percentage_of_total': [52.43, 47.57]},
#  {'campaign_id': 524,
#   'start_at': 1655715600000,
#   'end_at': 1655721000000,
#   'post_comment': 7,
#   'no_of_items_sold': 2,
#   'no_of_items_unsold': 2,
#   'total_no_of_items': 4,
#   'total_inventories': 310,
#   'total_no_of_orders': 2,
#   'total_amount': 340.0,
#   'average_order_value': 170.0,
#   'item': ['cecitest8', 'cecitest5gift', 'cecitest16', 'cc013'],
#   'qty_for_sale': [100, 10, 100, 100],
#   'best_selling_status': ['', '', '', ''],
#   'status': ['paid', 'unpaid'],
#   'qty': [1, 0],
#   'percentage_of_qty': [100.0, 0],
#   'total': [220.0, 0],
#   'percentage_of_total': [100.0, 0]},
#  {'campaign_id': 525,
#   'start_at': 1655718600000,
#   'end_at': 1655734500000,
#   'post_comment': 15,
#   'no_of_items_sold': 1,
#   'no_of_items_unsold': 1,
#   'total_no_of_items': 2,
#   'total_inventories': 50,
#   'total_no_of_orders': 6,
#   'total_amount': 29200.0,
#   'average_order_value': 14600.0,
#   'item': ['VAN0620', 'VAN0620'],
#   'qty_for_sale': [50, 0],
#   'best_selling_status': ['', 'Sold Out'],
#   'status': ['paid', 'unpaid'],
#   'qty': [0, 4],
#   'percentage_of_qty': [0, 100.0],
#   'total': [0, 28800.0],
#   'percentage_of_total': [0, 100.0]},
#  {'campaign_id': 639,
#   'start_at': 1655316633623,
#   'end_at': 1655403033623,
#   'post_comment': 0,
#   'no_of_items_sold': 0,
#   'no_of_items_unsold': 0,
#   'total_no_of_items': 0,
#   'total_inventories': 0,
#   'total_no_of_orders': 0,
#   'total_amount': 0.0,
#   'average_order_value': 0.0,
#   'item': [],
#   'qty_for_sale': [],
#   'best_selling_status': [],
#   'status': None,
#   'qty': None,
#   'percentage_of_qty': None,
#   'total': None,
#   'percentage_of_total': None}]

# %%
list_data = []
basic_info_keys = ['post_comment', 'no_of_items_sold', 'no_of_items_unsold', 'total_no_of_items', 
                   'total_inventories', 'total_no_of_orders', 'total_amount', 'average_order_value']
order_analysis_keys = ['status', 'qty', 'percentage_of_qty', 'total', 'percentage_of_total']
best_selling_items_top_10_keys = ['item', 'qty_for_sale', 'best_selling_status']

campaign_template = {
    "campaign_id":"",
    "start_at": "",
    "end_at": "",
    "basic_info": {},
    "order_analysis": {},
    "best_selling_items_top_10": {}
}
    
for row in json_data:
    new_row_data = copy.deepcopy(row)
    new_data = copy.deepcopy(campaign_template)
    for key in new_data:
        if key == "basic_info":
            for b_key in basic_info_keys:
                new_data[key][b_key] = new_row_data[b_key]
        elif key == "order_analysis":
            for o_key in order_analysis_keys:
                new_data[key][o_key] = new_row_data[o_key]
        elif key == "best_selling_items_top_10":
            for s_key in best_selling_items_top_10_keys:
                if s_key == "best_selling_status":
                    new_data[key]['status'] = new_row_data[s_key]
                else:
                    new_data[key][s_key] = new_row_data[s_key]
        else:
            new_data[key] = new_row_data[key]
    list_data.append(new_data.copy())
display("===============================================================")
display(list_data)
# Out:
# '==============================================================='
# [{'campaign_id': 494,
#   'start_at': 1655259000000,
#   'end_at': 1655450700000,
#   'basic_info': {'post_comment': 50,
#    'no_of_items_sold': 4,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 4,
#    'total_inventories': 216,
#    'total_no_of_orders': 16,
#    'total_amount': 32280.5,
#    'average_order_value': 16140.25},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [2, 11],
#    'percentage_of_qty': [15.38, 84.62],
#    'total': [322.0, 31758.5],
#    'percentage_of_total': [1.0, 99.0]},
#   'best_selling_items_top_10': {'item': ['Vegetable Box A',
#     'GSI Cooking Set',
#     'MSR 2person Tent',
#     'RC2 - Test'],
#    'qty_for_sale': [200, 10, 5, 1],
#    'status': ['', '', 'Sold Out', 'Sold Out']}},
#  {'campaign_id': 495,
#   'start_at': 1655276400000,
#   'end_at': 1655280000000,
#   'basic_info': {'post_comment': 2,
#    'no_of_items_sold': 1,
#    'no_of_items_unsold': 2,
#    'total_no_of_items': 3,
#    'total_inventories': 1000,
#    'total_no_of_orders': 1,
#    'total_amount': 15.99,
#    'average_order_value': 7.995},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [0, 1],
#    'percentage_of_qty': [0, 100.0],
#    'total': [0, 15.99],
#    'percentage_of_total': [0, 100.0]},
#   'best_selling_items_top_10': {'item': ['Top', 'Jeans', 'Skirt'],
#    'qty_for_sale': [200, 500, 300],
#    'status': ['', '', '']}},
#  {'campaign_id': 496,
#   'start_at': 1655277060000,
#   'end_at': 1655284320000,
#   'basic_info': {'post_comment': 4,
#    'no_of_items_sold': 4,
#    'no_of_items_unsold': 2,
#    'total_no_of_items': 6,
#    'total_inventories': 1050,
#    'total_no_of_orders': 3,
#    'total_amount': 159.9,
#    'average_order_value': 79.95},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 1],
#    'percentage_of_qty': [50.0, 50.0],
#    'total': [127.92, 31.98],
#    'percentage_of_total': [80.0, 20.0]},
#   'best_selling_items_top_10': {'item': ['grapegfruit',
#     'Pepsi',
#     'Skirt',
#     'Thai Meow Tea',
#     'prize yummy cookies',
#     'Prize - Bag'],
#    'qty_for_sale': [200, 300, 400, 100, 40, 10],
#    'status': ['', '', '', '', '', '']}},
#  {'campaign_id': 497,
#   'start_at': 1655282940000,
#   'end_at': 1655285700000,
#   'basic_info': {'post_comment': 14,
#    'no_of_items_sold': 1,
#    'no_of_items_unsold': 1,
#    'total_no_of_items': 2,
#    'total_inventories': 115,
#    'total_no_of_orders': 4,
#    'total_amount': 40.0,
#    'average_order_value': 20.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [2, 1],
#    'percentage_of_qty': [66.67, 33.33],
#    'total': [25.0, 15.0],
#    'percentage_of_total': [62.5, 37.5]},
#   'best_selling_items_top_10': {'item': ['nina0615', 'nina0615'],
#    'qty_for_sale': [100, 15],
#    'status': ['', '']}},
#  {'campaign_id': 499,
#   'start_at': 1655283000000,
#   'end_at': 1655285700000,
#   'basic_info': {'post_comment': 13,
#    'no_of_items_sold': 3,
#    'no_of_items_unsold': 1,
#    'total_no_of_items': 4,
#    'total_inventories': 400,
#    'total_no_of_orders': 2,
#    'total_amount': 8870.0,
#    'average_order_value': 4435.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 0],
#    'percentage_of_qty': [100.0, 0],
#    'total': [8870.0, 0],
#    'percentage_of_total': [100.0, 0]},
#   'best_selling_items_top_10': {'item': ['cc013',
#     'cecitest12',
#     'cecitest5gift',
#     'cecitest6'],
#    'qty_for_sale': [100, 100, 100, 100],
#    'status': ['', '', '', '']}},
#  {'campaign_id': 500,
#   'start_at': 1655288400000,
#   'end_at': 1655371200000,
#   'basic_info': {'post_comment': 10,
#    'no_of_items_sold': 2,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 2,
#    'total_inventories': 200,
#    'total_no_of_orders': 6,
#    'total_amount': 191.0,
#    'average_order_value': 95.5},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [2, 2],
#    'percentage_of_qty': [50.0, 50.0],
#    'total': [51.0, 140.0],
#    'percentage_of_total': [26.7, 73.3]},
#   'best_selling_items_top_10': {'item': ['Meja Lipat 100x40',
#     'Meja lipat 80x40'],
#    'qty_for_sale': [100, 100],
#    'status': ['', '']}},
#  {'campaign_id': 501,
#   'start_at': 1655286000000,
#   'end_at': 1655289600000,
#   'basic_info': {'post_comment': 16,
#    'no_of_items_sold': 2,
#    'no_of_items_unsold': 1,
#    'total_no_of_items': 3,
#    'total_inventories': 58,
#    'total_no_of_orders': 4,
#    'total_amount': 1660.0,
#    'average_order_value': 830.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 2],
#    'percentage_of_qty': [33.33, 66.67],
#    'total': [390.0, 1270.0],
#    'percentage_of_total': [23.49, 76.51]},
#   'best_selling_items_top_10': {'item': ['Lynn_0615',
#     '0608lynnlucky draw',
#     'll615_2'],
#    'qty_for_sale': [50, 3, 5],
#    'status': ['', '', '']}},
#  {'campaign_id': 502,
#   'start_at': 1655286600000,
#   'end_at': 1655290800000,
#   'basic_info': {'post_comment': 4,
#    'no_of_items_sold': 2,
#    'no_of_items_unsold': 2,
#    'total_no_of_items': 4,
#    'total_inventories': 900,
#    'total_no_of_orders': 2,
#    'total_amount': 29.54,
#    'average_order_value': 14.77},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [0, 1],
#    'percentage_of_qty': [0, 100.0],
#    'total': [0, 19.54],
#    'percentage_of_total': [0, 100.0]},
#   'best_selling_items_top_10': {'item': ['Top', 'b1', 'Jeans', 'Skirt'],
#    'qty_for_sale': [250, 150, 300, 200],
#    'status': ['', '', '', '']}},
#  {'campaign_id': 505,
#   'start_at': 1655449560000,
#   'end_at': 1655449560000,
#   'basic_info': {'post_comment': 0,
#    'no_of_items_sold': 0,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 0,
#    'total_inventories': 0,
#    'total_no_of_orders': 0,
#    'total_amount': 0.0,
#    'average_order_value': 0.0},
#   'order_analysis': {'status': None,
#    'qty': None,
#    'percentage_of_qty': None,
#    'total': None,
#    'percentage_of_total': None},
#   'best_selling_items_top_10': {'item': [], 'qty_for_sale': [], 'status': []}},
#  {'campaign_id': 506,
#   'start_at': 1655449320000,
#   'end_at': 1655449380000,
#   'basic_info': {'post_comment': 0,
#    'no_of_items_sold': 0,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 0,
#    'total_inventories': 0,
#    'total_no_of_orders': 0,
#    'total_amount': 0.0,
#    'average_order_value': 0.0},
#   'order_analysis': {'status': None,
#    'qty': None,
#    'percentage_of_qty': None,
#    'total': None,
#    'percentage_of_total': None},
#   'best_selling_items_top_10': {'item': [], 'qty_for_sale': [], 'status': []}},
#  {'campaign_id': 507,
#   'start_at': 1655450700000,
#   'end_at': 1655450700000,
#   'basic_info': {'post_comment': 4,
#    'no_of_items_sold': 2,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 2,
#    'total_inventories': 32,
#    'total_no_of_orders': 2,
#    'total_amount': 10683.0,
#    'average_order_value': 5341.5},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [0, 2],
#    'percentage_of_qty': [0, 100.0],
#    'total': [0, 10683.0],
#    'percentage_of_total': [0, 100.0]},
#   'best_selling_items_top_10': {'item': ['Vegetable Box A',
#     'MSR 2person Tent'],
#    'qty_for_sale': [30, 2],
#    'status': ['', 'Sold Out']}},
#  {'campaign_id': 508,
#   'start_at': 1655369520000,
#   'end_at': 1655376660000,
#   'basic_info': {'post_comment': 0,
#    'no_of_items_sold': 0,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 0,
#    'total_inventories': 0,
#    'total_no_of_orders': 0,
#    'total_amount': 0.0,
#    'average_order_value': 0.0},
#   'order_analysis': {'status': None,
#    'qty': None,
#    'percentage_of_qty': None,
#    'total': None,
#    'percentage_of_total': None},
#   'best_selling_items_top_10': {'item': [], 'qty_for_sale': [], 'status': []}},
#  {'campaign_id': 509,
#   'start_at': 1655434200000,
#   'end_at': 1655519040000,
#   'basic_info': {'post_comment': 103,
#    'no_of_items_sold': 1,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 1,
#    'total_inventories': 50,
#    'total_no_of_orders': 4,
#    'total_amount': 2700.0,
#    'average_order_value': 1350.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [0, 3],
#    'percentage_of_qty': [0, 100.0],
#    'total': [0, 2700.0],
#    'percentage_of_total': [0, 100.0]},
#   'best_selling_items_top_10': {'item': ['Edmark Smart Steam Brush'],
#    'qty_for_sale': [50],
#    'status': ['']}},
#  {'campaign_id': 510,
#   'start_at': 1655438820000,
#   'end_at': 1655456160000,
#   'basic_info': {'post_comment': 7,
#    'no_of_items_sold': 4,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 4,
#    'total_inventories': 1110,
#    'total_no_of_orders': 6,
#    'total_amount': 119.06,
#    'average_order_value': 59.53},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [2, 4],
#    'percentage_of_qty': [33.33, 66.67],
#    'total': [64.99, 54.07],
#    'percentage_of_total': [54.59, 45.41]},
#   'best_selling_items_top_10': {'item': ['prize yummy cookies',
#     'Thai Meow Tea',
#     'Pepsi',
#     '2362'],
#    'qty_for_sale': [10, 800, 200, 100],
#    'status': ['Sold Out', '', '', '']}},
#  {'campaign_id': 512,
#   'start_at': 1655453280000,
#   'end_at': 1655464020000,
#   'basic_info': {'post_comment': 11,
#    'no_of_items_sold': 2,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 2,
#    'total_inventories': 110,
#    'total_no_of_orders': 7,
#    'total_amount': 442.1,
#    'average_order_value': 221.05},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [2, 2],
#    'percentage_of_qty': [50.0, 50.0],
#    'total': [241.05, 81.05],
#    'percentage_of_total': [74.84, 25.16]},
#   'best_selling_items_top_10': {'item': ['Cheese Cake', 'prize cookie'],
#    'qty_for_sale': [100, 10],
#    'status': ['', '']}},
#  {'campaign_id': 513,
#   'start_at': 1655454660000,
#   'end_at': 1655456580000,
#   'basic_info': {'post_comment': 19,
#    'no_of_items_sold': 3,
#    'no_of_items_unsold': 1,
#    'total_no_of_items': 4,
#    'total_inventories': 256,
#    'total_no_of_orders': 4,
#    'total_amount': 2420.0,
#    'average_order_value': 1210.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [2, 1],
#    'percentage_of_qty': [66.67, 33.33],
#    'total': [1620.0, 800.0],
#    'percentage_of_total': [66.94, 33.06]},
#   'best_selling_items_top_10': {'item': ['PIZZA', 'SATAY', 'UTENSILS', '3659'],
#    'qty_for_sale': [150, 100, 5, 1],
#    'status': ['', '', '', '']}},
#  {'campaign_id': 514,
#   'start_at': 1655456160000,
#   'end_at': 1655459460000,
#   'basic_info': {'post_comment': 0,
#    'no_of_items_sold': 0,
#    'no_of_items_unsold': 3,
#    'total_no_of_items': 3,
#    'total_inventories': 110,
#    'total_no_of_orders': 0,
#    'total_amount': 0.0,
#    'average_order_value': 0.0},
#   'order_analysis': {'status': None,
#    'qty': None,
#    'percentage_of_qty': None,
#    'total': None,
#    'percentage_of_total': None},
#   'best_selling_items_top_10': {'item': ['Vegetable Box A',
#     'nina1',
#     'ninatest1'],
#    'qty_for_sale': [10, 100, 0],
#    'status': ['', '', 'Sold Out']}},
#  {'campaign_id': 515,
#   'start_at': 1655459400000,
#   'end_at': 1655462940000,
#   'basic_info': {'post_comment': 2,
#    'no_of_items_sold': 1,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 1,
#    'total_inventories': 100,
#    'total_no_of_orders': 2,
#    'total_amount': 11.0,
#    'average_order_value': 5.5},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 0],
#    'percentage_of_qty': [100.0, 0],
#    'total': [11.0, 0],
#    'percentage_of_total': [100.0, 0]},
#   'best_selling_items_top_10': {'item': ['ninatest0617'],
#    'qty_for_sale': [100],
#    'status': ['']}},
#  {'campaign_id': 516,
#   'start_at': 1655546220000,
#   'end_at': 1655632680000,
#   'basic_info': {'post_comment': 0,
#    'no_of_items_sold': 0,
#    'no_of_items_unsold': 2,
#    'total_no_of_items': 2,
#    'total_inventories': 100,
#    'total_no_of_orders': 0,
#    'total_amount': 0.0,
#    'average_order_value': 0.0},
#   'order_analysis': {'status': None,
#    'qty': None,
#    'percentage_of_qty': None,
#    'total': None,
#    'percentage_of_total': None},
#   'best_selling_items_top_10': {'item': ['Meja Lipat 100x40',
#     'Meja lipat 80x40'],
#    'qty_for_sale': [50, 50],
#    'status': ['', '']}},
#  {'campaign_id': 517,
#   'start_at': 1655461980000,
#   'end_at': 1655469240000,
#   'basic_info': {'post_comment': 9,
#    'no_of_items_sold': 2,
#    'no_of_items_unsold': 1,
#    'total_no_of_items': 3,
#    'total_inventories': 810,
#    'total_no_of_orders': 7,
#    'total_amount': 5769.0,
#    'average_order_value': 2884.5},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 5],
#    'percentage_of_qty': [16.67, 83.33],
#    'total': [5161.0, 573.0],
#    'percentage_of_total': [90.01, 9.99]},
#   'best_selling_items_top_10': {'item': ['Vegetable Box A',
#     'MSR 2person Tent',
#     'prize yummy cookies'],
#    'qty_for_sale': [200, 600, 10],
#    'status': ['', '', '']}},
#  {'campaign_id': 520,
#   'start_at': 1655712180000,
#   'end_at': 1655715480000,
#   'basic_info': {'post_comment': 9,
#    'no_of_items_sold': 3,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 3,
#    'total_inventories': 105,
#    'total_no_of_orders': 3,
#    'total_amount': 1060.0,
#    'average_order_value': 530.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 1],
#    'percentage_of_qty': [50.0, 50.0],
#    'total': [810.0, 250.0],
#    'percentage_of_total': [76.42, 23.58]},
#   'best_selling_items_top_10': {'item': ['ice cream', 'cookies', 'Lollies'],
#    'qty_for_sale': [50, 50, 5],
#    'status': ['', '', '']}},
#  {'campaign_id': 521,
#   'start_at': 1655712960000,
#   'end_at': 1655715420000,
#   'basic_info': {'post_comment': 10,
#    'no_of_items_sold': 3,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 3,
#    'total_inventories': 330,
#    'total_no_of_orders': 4,
#    'total_amount': 1840.0,
#    'average_order_value': 920.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 2],
#    'percentage_of_qty': [33.33, 66.67],
#    'total': [0.0, 1840.0],
#    'percentage_of_total': [0.0, 100.0]},
#   'best_selling_items_top_10': {'item': ['Yummy cake',
#     'prize yummy cookies',
#     'rr'],
#    'qty_for_sale': [100, 10, 220],
#    'status': ['', '', '']}},
#  {'campaign_id': 522,
#   'start_at': 1655714280000,
#   'end_at': 1655715480000,
#   'basic_info': {'post_comment': 4,
#    'no_of_items_sold': 1,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 1,
#    'total_inventories': 100,
#    'total_no_of_orders': 2,
#    'total_amount': 10.0,
#    'average_order_value': 5.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 0],
#    'percentage_of_qty': [100.0, 0],
#    'total': [10.0, 0],
#    'percentage_of_total': [100.0, 0]},
#   'best_selling_items_top_10': {'item': ['ninatest0620'],
#    'qty_for_sale': [100],
#    'status': ['']}},
#  {'campaign_id': 523,
#   'start_at': 1655715000000,
#   'end_at': 1655716620000,
#   'basic_info': {'post_comment': 11,
#    'no_of_items_sold': 3,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 3,
#    'total_inventories': 37,
#    'total_no_of_orders': 3,
#    'total_amount': 2060.0,
#    'average_order_value': 1030.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 1],
#    'percentage_of_qty': [50.0, 50.0],
#    'total': [1080.0, 980.0],
#    'percentage_of_total': [52.43, 47.57]},
#   'best_selling_items_top_10': {'item': ['lltest_0620',
#     '0608lynnlucky draw',
#     'Lynn_0615'],
#    'qty_for_sale': [20, 2, 15],
#    'status': ['', '', '']}},
#  {'campaign_id': 524,
#   'start_at': 1655715600000,
#   'end_at': 1655721000000,
#   'basic_info': {'post_comment': 7,
#    'no_of_items_sold': 2,
#    'no_of_items_unsold': 2,
#    'total_no_of_items': 4,
#    'total_inventories': 310,
#    'total_no_of_orders': 2,
#    'total_amount': 340.0,
#    'average_order_value': 170.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [1, 0],
#    'percentage_of_qty': [100.0, 0],
#    'total': [220.0, 0],
#    'percentage_of_total': [100.0, 0]},
#   'best_selling_items_top_10': {'item': ['cecitest8',
#     'cecitest5gift',
#     'cecitest16',
#     'cc013'],
#    'qty_for_sale': [100, 10, 100, 100],
#    'status': ['', '', '', '']}},
#  {'campaign_id': 525,
#   'start_at': 1655718600000,
#   'end_at': 1655734500000,
#   'basic_info': {'post_comment': 15,
#    'no_of_items_sold': 1,
#    'no_of_items_unsold': 1,
#    'total_no_of_items': 2,
#    'total_inventories': 50,
#    'total_no_of_orders': 6,
#    'total_amount': 29200.0,
#    'average_order_value': 14600.0},
#   'order_analysis': {'status': ['paid', 'unpaid'],
#    'qty': [0, 4],
#    'percentage_of_qty': [0, 100.0],
#    'total': [0, 28800.0],
#    'percentage_of_total': [0, 100.0]},
#   'best_selling_items_top_10': {'item': ['VAN0620', 'VAN0620'],
#    'qty_for_sale': [50, 0],
#    'status': ['', 'Sold Out']}},
#  {'campaign_id': 639,
#   'start_at': 1655316633623,
#   'end_at': 1655403033623,
#   'basic_info': {'post_comment': 0,
#    'no_of_items_sold': 0,
#    'no_of_items_unsold': 0,
#    'total_no_of_items': 0,
#    'total_inventories': 0,
#    'total_no_of_orders': 0,
#    'total_amount': 0.0,
#    'average_order_value': 0.0},
#   'order_analysis': {'status': None,
#    'qty': None,
#    'percentage_of_qty': None,
#    'total': None,
#    'percentage_of_total': None},
#   'best_selling_items_top_10': {'item': [], 'qty_for_sale': [], 'status': []}}]

# %%
report = SalesReport.output_data("2022-06-15", "2022-06-20")
# Out:
# --------------------------------------------------------------------
# AttributeError                     Traceback (most recent call last)
# Input In [230], in <cell line: 1>()
# ----> 1 report = SalesReport.output_data("2022-06-15", "2022-06-20")
#
# AttributeError: type object 'SalesReport' has no attribute 'output_data'
